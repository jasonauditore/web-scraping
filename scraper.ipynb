# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# Step 2: Send a GET request to the URL
base_url = "https://books.toscrape.com/catalogue/page-{}.html"
base_site_url = "https://books.toscrape.com/catalogue/"
for i in range(1,51):
    url = base_url.format(i)
    res=requests.get(url)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'html.parser')
    prices = soup.select('div p.price_color')
    title = soup.select('a[title]')
    
    for j in range(len(prices)):
        print(title[j].text+"-"+prices[j].text)
        
        link=book_link[j].get('href')
        book_url = urljoin(base_site_url, link)
        new_res=requests.get(book_url)
        new_soup=BeautifulSoup(new_res.text, 'html.parser')
        book_description = new_soup.select('div[id=product_description] + p')[0]
        print(book_description.getText())
# Out:
# A Light in the ...-Â£51.77
# ...

# %%
book_description = new_soup.select('div[id=product_description] + p')
print(book_description)
# Out:
# [<p>It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love th It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love that Silverstein. Need proof of his genius? RockabyeRockabye baby, in the treetopDon't you know a treetopIs no safe place to rock?And who put you up there,And your cradle, too?Baby, I think someone down here'sGot it in for you. Shel, you never s
# ...
